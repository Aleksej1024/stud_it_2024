# %% [markdown]
# #  Модуль 4

# %% [markdown]
# Реализация загрузки данных на сервер 1.2.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Реализация функционала предобрапботки данных 1.2.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Реализация метода списка доступных датасетов 1.2.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Реализация списка доступных моделей 1.2.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Выбор датасета 1.2.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Выбор модели 1.2.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Предсказание 1.2.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.7 инфа

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.2.10 1.2.11

# %% [markdown]
# ![image.png](attachment:image.png)
